# %% [markdown]
# Bước 1: Chuẩn bị dữ liệu
# Thông tin bộ dữ liệu:smallAffectNet
#
# *   Thông tin bộ dữ liệu:https://www.kaggle.com/datasets/noamsegal/affectnet-training-data
# *   Bộ gốc: smallAffectNet
#
#
#
# *   Cài đặt ultralytics
# *   Giải nén file zip

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/78.2 GB disk)

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8m-cls.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 32.7M/32.7M [00:00<00:00, 205MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 17043656 parameters, 0 gradients, 42.7 GFLOPs
#
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /content/zidane.jpg: 224x224 bow_tie 0.31, suit 0.17, groom 0.14, rugby_ball 0.04, whistle 0.03, 8.0ms
# Speed: 18.1ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.27 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.6/107.7 GB disk)

# %%
# !unzip /content/fetd_15.zip -d /content/fetd_15
# Out:
# Archive:  /content/fetd_15.zip
#    creating: /content/fetd_15/classify/
#    creating: /content/fetd_15/classify/predict/
#    creating: /content/fetd_15/classify/train/
#   inflating: /content/fetd_15/classify/predict/zidane.jpg
#    creating: /content/fetd_15/classify/train/weights/
#   inflating: /content/fetd_15/classify/train/train_batch5226.jpg
#   inflating: /content/fetd_15/classify/train/train_batch2.jpg
#   inflating: /content/fetd_15/classify/train/val_batch2_pred.jpg
#   inflating: /content/fetd_15/classify/train/val_batch1_pred.jpg
#   inflating: /content/fetd_15/classify/train/confusion_matrix.png
#   inflating: /content/fetd_15/classify/train/train_batch5227.jpg
#   inflating: /content/fetd_15/classify/train/val_batch0_pred.jpg
#   inflating: /content/fetd_15/classify/train/results.csv
#   inflating: /content/fetd_15/classify/train/val_batch1_labels.jpg
#   inflating: /content/fetd_15/classify/train/results.png
# ...

# %% [markdown]
# Bước 2: Train model

# %%
# Train YOLOv8n for 15 epochs
from ultralytics import YOLO
model = YOLO("yolov8n-cls.pt")

result = model.train(data='/content/fetd_well_process', epochs=15, imgsz=96)
# Out:
# Ultralytics YOLOv8.2.27 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Train YOLOv8n for 15 epochs with 15 epochs of training data
# !yolo train model="/content/fetd_15/classify/train/weights/last.pt" data="/content/fetd_well_process" epochs=15 imgsz=96
# Out:
# Ultralytics YOLOv8.2.27 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# Bước 3: Xuất file .zip và download

# %%
import shutil
folder_to_zip = '/content/runs'  # Đường dẫn đến folder bạn muốn tải
output_filename = '/content/fettd_30.zip'  # Đường dẫn và tên file ZIP sau khi nén

shutil.make_archive(output_filename.replace('.zip', ''), 'zip', folder_to_zip)
# Out:
# '/content/fettd_30.zip'
