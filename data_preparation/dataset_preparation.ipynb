# %% [markdown]
# **Bước 1. Chuẩn bị dữ liệu**
#
# - Thông tin bộ dữ liệu: https://www.kaggle.com/datasets/noamsegal/affectnet-training-data?select=fear
#
# - Bộ gốc: AffectNet
#
# - Liên kết tài khoản Google Drive để lấy bộ dữ liệu.
#
# - Giải nén file zip

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip /content/drive/MyDrive/Colab\ Notebooks/dataset/classification_task/Facial_Expressions_Training_Data.zip -d /content/drive/MyDrive/Colab\ Notebooks/dataset/classification_task
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025659.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025666.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025673.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025679.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025681.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025693.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025694.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025697.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/dataset/classification_task/sad/image0025715.jpg
# ...

# %%
import pandas as pd
import shutil
import os

# %%
begin_dir = '/content/'
result_dir = '/content/processed_data'

if not os.path.exists(result_dir) :
    os.mkdir(result_dir)

print(os.path.exists(result_dir))
# Out:
# True

# %% [markdown]
# **Bước 2. Đọc file labels.csv đi kèm để phân lại nhãn ảnh cho đúng**

# %%
labels = pd.read_csv('/content/labels.csv')


for index, img_address, class_name, cfdP in labels.values :

    if not os.path.exists(result_dir + '/' + str(class_name)) :
        os.mkdir(result_dir + '/' + str(class_name))


    src_path = begin_dir + img_address
    dst_path = result_dir + '/' + str(class_name)

    try:
        shutil.copy(src_path, dst_path)
        print("Success!")
    except:
        print('ERROR!'  + str(sys.exc_info()))

# %% [markdown]
# **Bước 3. Chia tập train/ val/ test cho bộ dữ liệu**
# - Tỷ lệ train/ val/ test = 60/ 20/ 20

# %%
# !pip install split-folders[full]

# %%
import splitfolders

input_folder = '/content/processed_data'

splitfolders.ratio(input_folder, output = "well_dataset", seed=1337, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 27864 files [00:16, 1717.98 files/s]

# %% [markdown]
# **Bước 4. Xuất file .zip để phục vụ quá trình train model**

# %%
folder_to_zip = '/content/well_dataset'
output_filename = '/content/well_dataset'

shutil.make_archive(output_filename.replace('.zip', ''), 'zip', folder_to_zip)
# Out:
# '/content/well_dataset.zip'
